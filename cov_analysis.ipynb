# %%
import pandas as pd

# %%
df = pd.read_csv("cov.csv")

# %%
df.head()
# Out:
#    HalfHourId                 Time  Value Variable    AssetId  \
# 0           1  2019-11-25 00:00:00 -100.0    power  abc123xyz
# 1           2  2019-11-25 00:30:00    0.0    power  abc123xyz
# 2           3  2019-11-25 01:00:00    0.0    power  abc123xyz
# 3           4  2019-11-25 01:30:00 -100.0    power  abc123xyz
# 4           5  2019-11-25 02:00:00    0.0    power  abc123xyz
#
#                         from                         to  forecast  actual  \
# 0  2019-11-24 23:30:00+00:00  2019-11-25 00:00:00+00:00       210     200
# 1  2019-11-25 00:00:00+00:00  2019-11-25 00:30:00+00:00       199     200
# 2  2019-11-25 00:30:00+00:00  2019-11-25 01:00:00+00:00       200     198
# 3  2019-11-25 01:00:00+00:00  2019-11-25 01:30:00+00:00       204     189
# 4  2019-11-25 01:30:00+00:00  2019-11-25 02:00:00+00:00       199     191
#
#       index
# 0  moderate
# 1  moderate
# 2  moderate
# 3  moderate
# 4  moderate

# %%
df[(df["HalfHourId"] >= 14) & (df["HalfHourId"] <= 20)]
# Out:
#     HalfHourId                 Time  Value Variable    AssetId  \
# 13          14  2019-11-25 06:30:00    0.0    power  abc123xyz
# 14          15  2019-11-25 07:00:00    0.0    power  abc123xyz
# 15          16  2019-11-25 07:30:00    0.0    power  abc123xyz
# 16          17  2019-11-25 08:00:00    0.0    power  abc123xyz
# 17          18  2019-11-25 08:30:00    0.0    power  abc123xyz
# 18          19  2019-11-25 09:00:00    0.0    power  abc123xyz
# 19          20  2019-11-25 09:30:00    0.0    power  abc123xyz
#
#                          from                         to  forecast  actual  \
# 13  2019-11-25 06:00:00+00:00  2019-11-25 06:30:00+00:00       210     255
# 14  2019-11-25 06:30:00+00:00  2019-11-25 07:00:00+00:00       242     272
# 15  2019-11-25 07:00:00+00:00  2019-11-25 07:30:00+00:00       272     283
# 16  2019-11-25 07:30:00+00:00  2019-11-25 08:00:00+00:00       293     283
# 17  2019-11-25 08:00:00+00:00  2019-11-25 08:30:00+00:00       290     278
# ...
